# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd      

html = requests.get("https://gravitas.acr.org/ACPortal/Index").text
soup = BeautifulSoup(html, "lxml")

records = []

# iterate over each row
for tr in soup.select("table tr"):
    # grab only the direct <td> children
    tds = tr.find_all("td", recursive=False)
    if len(tds) < 5:
        continue            # skip invalid rows

    scenario_id = tds[1].get_text(strip=True)   # 2nd <td>
    sex         = tds[3].get_text(strip=True)   # 4th <td>
    age         = tds[4].get_text(strip=True)   # 5th <td> RE-CHECK LATER

    if scenario_id:          # skip blank rows?
        records.append({
            "scenario_id": scenario_id,
            "sex": sex,
            "age": age
        })

# TEST
df = pd.DataFrame(records)
print(df.head())
# Out:
# /Users/satrio/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#   scenario_id          sex       age
# 0     3110141    Male Only  18 - 150
# 1     3194817  Female Only  18 - 150
# 2     3194815  Female Only  18 - 150
# 3     3194837  Female Only  18 - 150
# 4     3194835  Female Only  18 - 150

# %%
df_ssa = df

# %%
df_ssa[(df_ssa['scenario_id'] == '3199195')]
# Out:
#    scenario_id        sex       age
# 15     3199195  Male Only  25 - 150

# %%
df_acr = pd.read_csv('acr_scenarios.csv')
df_acr.head()
# Out:
#                                              variant  \
# 0  Male of any age with physical examination susp...
# 1  Male of any age with physical examination susp...
# 2  Male of any age with physical examination susp...
# 3  Male of any age with physical examination susp...
# 4  Male of any age with physical examination susp...
#
#                                        scenario  scenario_id  \
# 0  Axillary adenopathy, breast cancer suspected      3110141
# 1  Axillary adenopathy, breast cancer suspected      3110141
# 2  Axillary adenopathy, breast cancer suspected      3110141
# 3  Axillary adenopathy, breast cancer suspected      3110141
# 4  Axillary adenopathy, breast cancer suspected      3110141
#
#                                  procedure    adult_rrl       peds_rrl  \
# 0                                US breast      0 mSv O  0 mSv [ped] O
# 1  Digital breast tomosynthesis diagnostic  0.1-1mSv ☢☢            NaN
# 2                   Mammography diagnostic  0.1-1mSv ☢☢            NaN
# 3  MRI breast without and with IV contrast      0 mSv O  0 mSv [ped] O
# 4           MRI breast without IV contrast      0 mSv O  0 mSv [ped] O
#
#   appropriateness_category
# 0      Usually appropriate
# 1      Usually appropriate
# 2      Usually appropriate
# 3  Usually not appropriate
# 4  Usually not appropriate

# %%
df_ssa['scenario_id'] = df_ssa['scenario_id'].astype(int)

# %%
df_new = df_acr.merge(df_ssa, how='left', on='scenario_id')

# %%
df_new[df_new['scenario_id'] == 3198761]
# Out:
#                                                  variant  \
# 56772  Adult or child. Chylothorax: traumatic or iatr...
# 56773  Adult or child. Chylothorax: traumatic or iatr...
# 56774  Adult or child. Chylothorax: traumatic or iatr...
# 56775  Adult or child. Chylothorax: traumatic or iatr...
# 56776  Adult or child. Chylothorax: traumatic or iatr...
# 56777  Adult or child. Chylothorax: traumatic or iatr...
# 56778  Adult or child. Chylothorax: traumatic or iatr...
# 56779  Adult or child. Chylothorax: traumatic or iatr...
# 56780  Adult or child. Chylothorax: traumatic or iatr...
# 56781  Adult or child. Chylothorax: traumatic or iatr...
# 56782  Adult or child. Chylothorax: traumatic or iatr...
# 56783  Adult or child. Chylothorax: traumatic or iatr...
# 56784  Adult or child. Chylothorax: traumatic or iatr...
# 56785  Adult or child. Chylothorax: traumatic or iatr...
# 56786  Adult or child. Chylothorax: traumatic or iatr...
# 56787  Adult or child. Chylothorax: traumatic or iatr...
# 56788  Adult or child. Chylothorax: traumatic or iatr...
# 56789  Adult or child. Chylothorax: traumatic or iatr...
#
#                                                 scenario  scenario_id  \
# 56772  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56773  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56774  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56775  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56776  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56777  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56778  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56779  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56780  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56781  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56782  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56783  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56784  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56785  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56786  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56787  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56788  Chylothorax, traumatic etiology, treatment pla...      3198761
# 56789  Chylothorax, traumatic etiology, treatment pla...      3198761
#
#                                                procedure       adult_rrl  \
# 56772              Lymphangiography chest abdomen pelvis    1-10 mSv ☢☢☢
# 56773                 Lymphangiography chest and abdomen    1-10 mSv ☢☢☢
# 56774           MR lymphangiography chest abdomen pelvis         0 mSv O
# 56775              MR lymphangiography chest and abdomen         0 mSv O
# 56776                                  Radiography chest      <0.1 mSv ☢
# 56777                   Radiography chest abdomen pelvis    1-10 mSv ☢☢☢
# 56778             MRI chest without and with IV contrast         0 mSv O
# 56779                      MRI chest without IV contrast         0 mSv O
# 56780            Lymphoscintigraphy chest abdomen pelvis     0.1-1mSv ☢☢
# 56781               Lymphoscintigraphy chest and abdomen     0.1-1mSv ☢☢
# 56782                          CT chest with IV contrast    1-10 mSv ☢☢☢
# 56783              CT chest without and with IV contrast    1-10 mSv ☢☢☢
# 56784                       CT chest without IV contrast    1-10 mSv ☢☢☢
# 56785           CT chest abdomen pelvis with IV contrast  10-30 mSv ☢☢☢☢
# 56786  CT chest abdomen pelvis without and with IV co...  10-30 mSv ☢☢☢☢
# 56787        CT chest abdomen pelvis without IV contrast  10-30 mSv ☢☢☢☢
# 56788                                           US chest         0 mSv O
# 56789                            US chest abdomen pelvis         0 mSv O
#
#                     peds_rrl appropriateness_category  sex      age
# 56772    3-10 mSv [ped] ☢☢☢☢      Usually appropriate  All  0 - 150
# 56773    3-10 mSv [ped] ☢☢☢☢      Usually appropriate  All  0 - 150
# 56774          0 mSv [ped] O      Usually appropriate  All  0 - 150
# 56775          0 mSv [ped] O      Usually appropriate  All  0 - 150
# 56776      <0.03 mSv [ped] ☢       May be appropriate  All  0 - 150
# 56777    0.3-3 mSv [ped] ☢☢☢       May be appropriate  All  0 - 150
# 56778          0 mSv [ped] O       May be appropriate  All  0 - 150
# 56779          0 mSv [ped] O       May be appropriate  All  0 - 150
# 56780    0.3-3 mSv [ped] ☢☢☢       May be appropriate  All  0 - 150
# 56781    0.3-3 mSv [ped] ☢☢☢       May be appropriate  All  0 - 150
# 56782    3-10 mSv [ped] ☢☢☢☢       May be appropriate  All  0 - 150
# 56783    3-10 mSv [ped] ☢☢☢☢       May be appropriate  All  0 - 150
# 56784    3-10 mSv [ped] ☢☢☢☢       May be appropriate  All  0 - 150
# 56785    3-10 mSv [ped] ☢☢☢☢       May be appropriate  All  0 - 150
# 56786  10-30 mSv [ped] ☢☢☢☢☢       May be appropriate  All  0 - 150
# 56787    3-10 mSv [ped] ☢☢☢☢       May be appropriate  All  0 - 150
# 56788          0 mSv [ped] O  Usually not appropriate  All  0 - 150
# 56789          0 mSv [ped] O  Usually not appropriate  All  0 - 150

# %%
new_order = ['variant','scenario_id','scenario','age','sex','procedure','adult_rrl','peds_rrl','appropriateness_category']

# %%
df_ordered = df_new[new_order]

# %%
df_ordered
# Out:
#                                                  variant  scenario_id  \
# 0      Male of any age with physical examination susp...      3110141
# 1      Male of any age with physical examination susp...      3110141
# 2      Male of any age with physical examination susp...      3110141
# 3      Male of any age with physical examination susp...      3110141
# 4      Male of any age with physical examination susp...      3110141
# ...                                                  ...          ...
# 59465                       Venous leg ulcer. Treatment.      3196594
# 59466                       Venous leg ulcer. Treatment.      3196594
# 59467                       Venous leg ulcer. Treatment.      3196594
# 59468                       Venous leg ulcer. Treatment.      3196594
# 59469                       Venous leg ulcer. Treatment.      3196594
#
#                                            scenario       age        sex  \
# 0      Axillary adenopathy, breast cancer suspected  18 - 150  Male Only
# 1      Axillary adenopathy, breast cancer suspected  18 - 150  Male Only
# 2      Axillary adenopathy, breast cancer suspected  18 - 150  Male Only
# 3      Axillary adenopathy, breast cancer suspected  18 - 150  Male Only
# 4      Axillary adenopathy, breast cancer suspected  18 - 150  Male Only
# ...                                             ...       ...        ...
# 59465  Venous leg ulcer, lower extremity, treatment  18 - 150        All
# 59466  Venous leg ulcer, lower extremity, treatment  18 - 150        All
# 59467  Venous leg ulcer, lower extremity, treatment  18 - 150        All
# 59468  Venous leg ulcer, lower extremity, treatment  18 - 150        All
# 59469  Venous leg ulcer, lower extremity, treatment  18 - 150        All
#
#                                      procedure    adult_rrl       peds_rrl  \
# 0                                    US breast      0 mSv O  0 mSv [ped] O
# 1      Digital breast tomosynthesis diagnostic  0.1-1mSv ☢☢            NaN
# 2                       Mammography diagnostic  0.1-1mSv ☢☢            NaN
# 3      MRI breast without and with IV contrast      0 mSv O  0 mSv [ped] O
# 4               MRI breast without IV contrast      0 mSv O  0 mSv [ped] O
# ...                                        ...          ...            ...
# 59465                      Iliac vein stenting          NaN            NaN
# 59466                   Ligation and stripping          NaN            NaN
# 59467                   Ligation and stripping          NaN            NaN
# 59468                         Microphlebectomy          NaN            NaN
# 59469                         Microphlebectomy          NaN            NaN
#
#       appropriateness_category
# 0          Usually appropriate
# 1          Usually appropriate
# 2          Usually appropriate
# 3      Usually not appropriate
# 4      Usually not appropriate
# ...                        ...
# 59465       May be appropriate
# 59466       May be appropriate
# 59467       May be appropriate
# 59468       May be appropriate
# 59469       May be appropriate
#
# [59470 rows x 9 columns]

# %%
df_ordered.to_csv('acr_scenarios_complete_ordered.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_ordered.to_csv('acr_scenarios_complete_ordered.csv',index=False)
#
# NameError: name 'df_ordered' is not defined
